# %%
import json
import pandas as pd
def students_list():
    with open('static/competencias.json', 'r', encoding='utf-8') as archivo_json:
        data = json.load(archivo_json)
        df = pd.DataFrame(data)
        df = df.drop_duplicates(subset='numero_documento', keep='first')
        df['nombre_completo'] = df['nombre'] + ' ' + df['apellidos']
        df = df[['numero_documento', 'nombre_completo']]
        df = df.sort_values(by='nombre_completo', ascending=True)
        df = df.reset_index(drop=True)
        df = df.to_dict(orient='records')
        return df
    
print(students_list())
# Out:
# [{'numero_documento': '1001503809', 'nombre_completo': 'ABEL YESITH BELLO PALACIOS'}, {'numero_documento': '1032176974', 'nombre_completo': 'ADOLFO MARTINEZ MOSQUERA'}, {'numero_documento': '1032177449', 'nombre_completo': 'ADONAY ISABEL VILLA MUÑOZ'}, {'numero_documento': '1000099839', 'nombre_completo': 'ADRIAN AGUIRRE RODRIGUEZ'}, {'numero_documento': '1033180760', 'nombre_completo': 'ADRIAN CAMILO RAMIREZ JARAMILLO'}, {'numero_documento': '1063359905', 'nombre_completo': 'ADRIAN SMIT CASTRO ARGUMEDO'}, {'numero_documento': '43726569', 'nombre_completo': 'ADRIANA PATRICIA SEPULVEDA PIEDRAHITA'}, {'numero_documento': '1071431929', 'nombre_completo': 'AIDER DIAZ MESTRA'}, {'numero_documento': '1021804626', 'nombre_completo': 'ALAN ANDREY SANCHEZ CARO'}, {'numero_documento': '1045488423', 'nombre_completo': 'ALAN GUEVARA NEGRETTE'}, {'numero_documento': '1017256993', 'nombre_completo': 'ALDAIR ANDRES SALAZAR MEJIA'}, {'numero_documento': '1023592129', 'nombre_completo': 'ALEISON DIAZ GARCIA'}, {'numero_documento': '1000086048', 'nombre_completo': 'ALEJANDRA AGUDELO CARTAGENA'}, {'numero_documento': '1020105787', 'nombre_completo': 'ALEJANDRA AGUIRRE MEJIA'}, {'numero_documento': '1069468012', 'nombre_completo': 'ALEJANDRA DIAZ LOZANO'}, {'numero_documento': '1013341074', 'nombre_completo': 'ALEJANDRA HENAO MUÑOZ'}, {'numero_documento': '1005153336', 'nombre_completo': 'ALEJANDRA LOPEZ GARCIA'}, {'numero_documento': '1015070068', 'nombre_completo': 'ALEJANDRA MARIA ESCOBAR VELEZ'}, {'numero_documento': '1000291933', 'nombre_completo': 'ALEJANDRA MARIA ESPINOSA CARDOZO'}, {'numero_documento': '1000292757', 'nombre_completo': 'ALEJANDRA MONTOYA ZAPATA'}, {'numero_documento': '1033179432', 'nombre_completo': 'ALEJANDRA SANCHEZ DUQUE'}, {'numero_documento': '1017209268', 'nombre_completo': 'ALEJANDRA SANTANA GAVIRIA'}, {'numero_documento': '1036661913', 'nombre_completo': 'ALEJANDRO AGUDELO OCAMPO'}, {'numero_documento': '8028413', 'nombre_completo': 'ALEJANDRO ARBELAEZ ACEVEDO'}, {'numero_documento': '1035416739', 'nombre_completo': 'ALEJANDRO ARIAS ECHAVARRIA'}, {'numero_documento': '1017132825', 'nombre_completo': 'ALEJANDRO BOTERO HINCAPIE'}, {'numero_documento': '1152223703', 'nombre_completo': 'ALEJANDRO BUILES RESTREPO'}, {'numero_documento': '1017926879', 'nombre_completo': 'ALEJANDRO CARO ARENAS'}, {'numero_documento': '1040873086', 'nombre_completo': 'ALEJANDRO CASTAÑEDA ARBELAEZ'}, {'numero_documento': '1001505925', 'nombre_completo': 'ALEJANDRO CAÑAS ARANGO'}, {'numero_documento': '1011396479', 'nombre_completo': 'ALEJANDRO GALEANO VELEZ'}, {'numero_documento': '1000085670', 'nombre_completo': 'ALEJANDRO LONDOÑO HENAO'}, {'numero_documento': '1025644797', 'nombre_completo': 'ALEJANDRO MEJIA BERMUDEZ'}, {'numero_documento': '1033177602', 'nombre_completo': 'ALEJANDRO OCAMPO ANGEL'}, {'numero_documento': '1193118709', 'nombre_completo': 'ALEJANDRO PEREIRA TORRES'}, {'numero_documento': '1039680559', 'nombre_completo': 'ALEJANDRO QUINTERO SANCHEZ'}, {'numero_documento': '1025880332', 'nombre_completo': 'ALEJANDRO RUA MUÑOZ'}, {'numero_documento': '1025762389', 'nombre_completo': 'ALEJANDRO RUIZ BENITEZ'}, {'numero_documento': '1025883294', 'nombre_completo': 'ALEJANDRO SALAZAR AGUDELO'}, {'numero_documento': '1020484855', 'nombre_completo': 'ALEJANDRO SALDARRIAGA MEJIA'}, {'numero_documento': '1001015026', 'nombre_completo': 'ALEJANDRO SALINAS MORENO'}, {'numero_documento': '1036662656', 'nombre_completo': 'ALEJANDRO SANCHEZ ARANGO'}, {'numero_documento': '1023623740', 'nombre_completo': 'ALEJANDRO SANCHEZ EMITOLA'}, {'numero_documento': '1000203092', 'nombre_completo': 'ALEJANDRO VELASQUEZ CORRALES'}, {'numero_documento': '1192898991', 'nombre_completo': 'ALEJANDRO VELEZ GRANADOS'}, {'numero_documento': '1011510487', 'nombre_completo': 'ALEJANDRO VIVERO PEREZ'}, {'numero_documento': '1003969429', 'nombre_completo': 'ALESANDER VALOIS MORENO'}, {'numero_documento': '1001525495', 'nombre_completo': 'ALEX DAVID ZULUAGA CARDON ...

# %%
def performance_students(numero_documento):
    with open('static/competencias.json', 'r', encoding='utf-8') as archivo_json:
        data = json.load(archivo_json)
        df = pd.DataFrame(data)
        df = df[df['numero_documento'] == numero_documento]        
        total = df['rap'].value_counts().reset_index()
        approved = df[df['juicio'] == 'APROBADO']
        no_approved = df[df['juicio'] == 'NO APROBADO']
        total_approved = len(approved)
        total_no_approved = len(no_approved)
        percentage_approved = (total_approved / len(total)) * 100
        percentage_no_approved = (total_no_approved / len(total)) * 100
        performance_student = ""
        if percentage_approved >= 99:
            performance_student = "Alto"
        elif percentage_no_approved >= 1:
            performance_student = "Bajo"
        else:
            performance_student = "Bueno"

        performance = {
            "name_student" : df['nombre'].iloc[0] + ' ' + df['apellidos'].iloc[0],
            "status": df['estado'].iloc[0],
            "program": df['programa'].iloc[0],
            "total_approved": total_approved,
            "total_no_approved": total_no_approved,
            "percentage_approved": percentage_approved,
            "percentage_no_approved": percentage_no_approved,
            "performance_student": performance_student
        }
        
        return performance
        
        
print(performance_students('1001503809'))
# Out:
# {'name_student': 'ABEL YESITH BELLO PALACIOS', 'status': 'EN FORMACION', 'program': 'ANALISIS Y DESARROLLO DE SOFTWARE.', 'total_approved': 11, 'total_no_approved': 0, 'percentage_approved': 14.666666666666666, 'percentage_no_approved': 0.0, 'performance_student': 'Bueno'}
